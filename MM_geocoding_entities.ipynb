# %% [markdown]
# #### Date: July 2021
# #### Project: Mass Mobilizations dataset - Geocoding protest event locations
# #### Author: Almira Sadykova-DuMond

# %%
#Importing libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from geopy.geocoders import ArcGIS
nom = ArcGIS(timeout=300)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
#setting wd
import os
path ="C:/Users/16073/Desktop/MM" #setting the path to the new directory
os.chdir(path) # changing the directory
os.getcwd() # getting the changed directory
# Out:
# 'C:\\Users\\16073\\Desktop\\MM'

# %%
mm = pd.read_csv('mm_entities.csv')
print(mm)
# Out:
#                id           country  ccode  year         region  protest  \
# 0       201990001            Canada     20  1990  North America        1
# 1       201990002            Canada     20  1990  North America        1
# 2       201990003            Canada     20  1990  North America        1
# 3       201990004            Canada     20  1990  North America        1
# 4       201990005            Canada     20  1990  North America        1
# ...           ...               ...    ...   ...            ...      ...
# 17140  8302020000         Singapore    830  2020           Asia        0
# 17141  8402020000       Philippines    840  2020           Asia        0
# 17142  8502020001         Indonesia    850  2020           Asia        1
# 17143  8602020000       Timor Leste    860  2020           Asia        0
# 17144  9102020000  Papua New Guinea    910  2020        Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...    9   10   11  \
# ...

# %%
#Adding country names to city/location names for more precision

mm['0'] = mm['0'] +','+ mm['country']
mm['1'] = mm['1'] +','+ mm['country']
mm['2'] = mm['2'] +','+ mm['country']
mm['3'] = mm['3'] +','+ mm['country']
mm['4'] = mm['4'] +','+ mm['country']
mm['5'] = mm['5'] +','+ mm['country']
mm['6'] = mm['6'] +','+ mm['country']
mm['7'] = mm['7'] +','+ mm['country']
mm['8'] = mm['8'] +','+ mm['country']
mm['9'] = mm['9'] +','+ mm['country']
mm['10'] = mm['10'] +','+ mm['country']
mm['11'] = mm['11'] +','+ mm['country']
mm['12'] = mm['12'] +','+ mm['country']
mm['13'] = mm['13'] +','+ mm['country']
mm['14'] = mm['14'] +','+ mm['country']
mm['15'] = mm['15'] +','+ mm['country']
mm['16'] = mm['16'] +','+ mm['country']
mm['17'] = mm['17'] +','+ mm['country']
mm['18'] = mm['18'] +','+ mm['country']

# %%
mm['0']
# Out:
# 0                       NaN
# 1         'Montreal',Canada
# 2         'Montreal',Canada
# 3         'Montreal',Canada
# 4         'Montreal',Canada
#                 ...
# 17140                   NaN
# 17141                   NaN
# 17142    'Natuna',Indonesia
# 17143                   NaN
# 17144                   NaN
# Name: 0, Length: 17145, dtype: object

# %%
# replacing NaN values with an empty string
mm['0'] = mm['0'].fillna("")
mm['1'] = mm['1'].fillna("")
mm['2'] = mm['2'].fillna("")
mm['3'] = mm['3'].fillna("")
mm['4'] = mm['4'].fillna("")
mm['5'] = mm['5'].fillna("")
mm['6'] = mm['6'].fillna("")
mm['7'] = mm['7'].fillna("")
mm['8'] = mm['8'].fillna("")
mm['9'] = mm['9'].fillna("")
mm['10'] = mm['10'].fillna("")
mm['11'] = mm['11'].fillna("")
mm['12'] = mm['12'].fillna("")
mm['13'] = mm['13'].fillna("")
mm['14'] = mm['14'].fillna("")
mm['15'] = mm['15'].fillna("")
mm['16'] = mm['16'].fillna("")
mm['17'] = mm['17'].fillna("")
mm['18'] = mm['18'].fillna("")

# %%
mm['0']
# Out:
# 0
# 1         'Montreal',Canada
# 2         'Montreal',Canada
# 3         'Montreal',Canada
# 4         'Montreal',Canada
#                 ...
# 17140
# 17141
# 17142    'Natuna',Indonesia
# 17143
# 17144
# Name: 0, Length: 17145, dtype: object

# %%
# After multiple attempts, I decided that going year by year will be a better approach. Hence, subsetting data to extract year 1990.
mm_sub=mm[mm.year == 1990]

# %%
print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  9  10  11  12 13 14  \
# ...

# %%
# printing out a column that will be geocoded
mm_sub["0"]
# Out:
# 0
# 1                    'Montreal',Canada
# 2                    'Montreal',Canada
# 3                    'Montreal',Canada
# 4                    'Montreal',Canada
#                     ...
# 625               'Manila',Philippines
# 626             'East Timor',Indonesia
# 627         'Tabubil',Papua New Guinea
# 628    'Port Moresby',Papua New Guinea
# 629        'Kundiawa',Papua New Guinea
# Name: 0, Length: 630, dtype: object

# %%
# Geocoding protect locations and saving latitude and longitude data in separate variables. Repeating this procedure for every column with protest location. 
mm_sub['Coordinates0'] = mm_sub['0'].apply(nom.geocode)
mm_sub["Latitude0"] = mm_sub["Coordinates0"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude0"] = mm_sub["Coordinates0"].apply(lambda x: 
                                x.longitude if x != None else None)


print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  12  13  14  15 16  \
# ...

# %%
mm_sub['Coordinates1'] = mm_sub['1'].apply(nom.geocode)
mm_sub["Latitude1"] = mm_sub["Coordinates1"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude1"] = mm_sub["Coordinates1"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  15  16  17  18  \
# ...

# %%
mm_sub['Coordinates2'] = mm_sub['2'].apply(nom.geocode)
mm_sub["Latitude2"] = mm_sub["Coordinates2"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude2"] = mm_sub["Coordinates2"].apply(lambda x: 
                                x.longitude if x != None else None)

print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  18  \
# ...

# %%
mm_sub['Coordinates3'] = mm_sub['3'].apply(nom.geocode)
mm_sub["Latitude3"] = mm_sub["Coordinates3"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude3"] = mm_sub["Coordinates3"].apply(lambda x: 
                                x.longitude if x != None else None)

print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  Longitude0  \
# ...

# %%
mm_sub['Coordinates4'] = mm_sub['4'].apply(nom.geocode)
mm_sub["Latitude4"] = mm_sub["Coordinates4"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude4"] = mm_sub["Coordinates4"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  Longitude1  \
# ...

# %%
mm_sub['Coordinates5'] = mm_sub['5'].apply(nom.geocode)
mm_sub["Latitude5"] = mm_sub["Coordinates5"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude5"] = mm_sub["Coordinates5"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  Longitude2  \
# ...

# %%
mm_sub['Coordinates6'] = mm_sub['6'].apply(nom.geocode)
mm_sub["Latitude6"] = mm_sub["Coordinates6"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude6"] = mm_sub["Coordinates6"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates7'] = mm_sub['7'].apply(nom.geocode)
mm_sub["Latitude7"] = mm_sub["Coordinates7"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude7"] = mm_sub["Coordinates7"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates8'] = mm_sub['8'].apply(nom.geocode)
mm_sub["Latitude8"] = mm_sub["Coordinates8"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude8"] = mm_sub["Coordinates8"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
mm_sub['Coordinates9'] = mm_sub['9'].apply(nom.geocode)
mm_sub["Latitude9"] = mm_sub["Coordinates9"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude9"] = mm_sub["Coordinates9"].apply(lambda x: 
                                x.longitude if x != None else None)


print(mm_sub)
# Out:
#              id           country  ccode  year         region  protest  \
# 0     201990001            Canada     20  1990  North America        1
# 1     201990002            Canada     20  1990  North America        1
# 2     201990003            Canada     20  1990  North America        1
# 3     201990004            Canada     20  1990  North America        1
# 4     201990005            Canada     20  1990  North America        1
# ..          ...               ...    ...   ...            ...      ...
# 625  8401990005       Philippines    840  1990           Asia        1
# 626  8501990001         Indonesia    850  1990           Asia        1
# 627  9101990001  Papua New Guinea    910  1990        Oceania        1
# 628  9101990002  Papua New Guinea    910  1990        Oceania        1
# 629  9101990003  Papua New Guinea    910  1990        Oceania        1
#
#      protestnumber  startday  startmonth  startyear  ...  Longitude6  \
# ...

# %%
mm_sub['Coordinates10'] = mm_sub['10'].apply(nom.geocode)
mm_sub["Latitude10"] = mm_sub["Coordinates10"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude10"] = mm_sub["Coordinates10"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates11'] = mm_sub['11'].apply(nom.geocode)
mm_sub["Latitude11"] = mm_sub["Coordinates11"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude11"] = mm_sub["Coordinates11"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
mm_sub['Coordinates12'] = mm_sub['12'].apply(nom.geocode)
mm_sub["Latitude12"] = mm_sub["Coordinates12"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude12"] = mm_sub["Coordinates12"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates13'] = mm_sub['13'].apply(nom.geocode)
mm_sub["Latitude13"] = mm_sub["Coordinates13"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude13"] = mm_sub["Coordinates13"].apply(lambda x: 
                                x.longitude if x != None else None)
mm_sub['Coordinates14'] = mm_sub['14'].apply(nom.geocode)
mm_sub["Latitude14"] = mm_sub["Coordinates14"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude14"] = mm_sub["Coordinates14"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
mm_sub['Coordinates15'] = mm_sub['15'].apply(nom.geocode)
mm_sub["Latitude15"] = mm_sub["Coordinates15"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude15"] = mm_sub["Coordinates15"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates16'] = mm_sub['16'].apply(nom.geocode)
mm_sub["Latitude16"] = mm_sub["Coordinates16"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude16"] = mm_sub["Coordinates16"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates17'] = mm_sub['17'].apply(nom.geocode)
mm_sub["Latitude17"] = mm_sub["Coordinates17"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude17"] = mm_sub["Coordinates17"].apply(lambda x: 
                                x.longitude if x != None else None)

mm_sub['Coordinates18'] = mm_sub['18'].apply(nom.geocode)
mm_sub["Latitude18"] = mm_sub["Coordinates18"].apply(lambda x: 
                               x.latitude if x != None else None)
mm_sub["Longitude18"] = mm_sub["Coordinates18"].apply(lambda x: 
                                x.longitude if x != None else None)
print(mm_sub)
# Out:
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\16073\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
mm_sub.to_csv('mm_entities_coord1990.csv', index=False)
